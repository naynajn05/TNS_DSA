# %% [markdown]
# ##  Tree — DSA Theory
#
# A **Tree** is a hierarchical, non-linear data structure made up of nodes connected via edges.
# It’s widely used to represent hierarchical relationships, like file systems, organization charts, or decision processes.
#
# ---
#
# ##  Characteristics:
# - **Root Node:** Topmost node (no parent)
# - **Parent-Child Relationship:** Each node can have multiple children but only one parent.
# - **Leaf Node:** Node with no children
# - **Internal Node:** Node with at least one child
# - **Edge:** Connection between two nodes
# - **Height:** Length of the longest path from root to a leaf
# - **Depth:** Length of the path from root to that node
#
# ---
#
# ##  Types of Trees:
#
# | Type                | Description                          |
# |:--------------------|:-------------------------------------|
# | **Binary Tree**       | Each node has ≤ 2 children.         |
# | **Binary Search Tree**| Left child < parent < right child   |
# | **Balanced Tree**     | Heights of left & right subtrees differ by ≤ 1 |
# | **Full Binary Tree**  | Every node has 0 or 2 children      |
# | **Complete Binary Tree** | All levels filled except last   |
# | **AVL Tree**          | Self-balancing BST                  |
# | **N-ary Tree**        | Each node can have ≤ N children     |
#
# ---
#
# ##  Applications in DSA & ML:
# - Expression parsing (Expression Tree)
# - Decision Trees (classification/regression)
# - Huffman Encoding
# - K-D Trees for KNN, clustering
# - Min/Max Heaps (priority queues)
# - Game trees (Minimax, Alpha-Beta pruning)
#
# ## 📖 Comparison Table: Types of Trees
#
# | Tree Type               | Characteristics                                                                 | Max Children per Node | Balanced?       | Use Cases                                              |
# |:------------------------|:--------------------------------------------------------------------------------|:---------------------|:----------------|:--------------------------------------------------------|
# | **Binary Tree**           | Each node has ≤ 2 children                                                      | 2                     | Not necessarily | Basic hierarchical structures, expression trees        |
# | **Binary Search Tree (BST)**| Left child < parent < right child                                             | 2                     | Not necessarily | Fast search, insert, delete (if balanced)              |
# | **Full Binary Tree**      | Every node has either 0 or 2 children                                           | 2                     | Not necessarily | Specific structural problems, parsing expressions      |
# | **Complete Binary Tree**  | All levels completely filled except possibly the last, filled left to right     | 2                     | Not necessarily | Heaps, Priority Queues                                 |
# | **Perfect Binary Tree**   | All internal nodes have 2 children and all leaves at same level                 | 2                     | Yes             | Theoretical, tree height problems                      |
# | **Balanced Binary Tree**  | Heights of left and right subtrees differ by at most 1                          | 2                     | Yes             | Ensures optimal O(log n) operations                    |
# | **AVL Tree**              | Self-balancing BST (rotations on insert/delete to maintain balance)             | 2                     | Yes             | Dynamic sorted datasets with frequent operations        |
# | **Red-Black Tree**        | Self-balancing BST with coloring rules to ensure balancing                      | 2                     | Yes             | OS scheduling, STL maps & sets, database indexes       |
# | **N-ary Tree**            | Each node can have ≤ N children                                                 | N                     | Not necessarily | General hierarchical data like JSON/XML parsers         |
# | **Ternary Tree**          | Each node has ≤ 3 children                                                      | 3                     | Not necessarily | Decision trees, expression parsing                     |
# | **Heap (Min/Max)**        | Complete binary tree maintaining heap property (min or max at root)             | 2                     | Yes (Complete)  | Priority Queues, job scheduling, Dijkstra's Algorithm  |
# | **Segment Tree**          | Binary tree used for storing intervals/segments                                 | 2                     | Yes             | Range query problems, dynamic array operations         |
# | **K-D Tree**              | Multidimensional binary search tree                                             | 2                     | Not necessarily | KNN, spatial indexing in ML and computer graphics      |

# %% [markdown]
# ## Binary Tree

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data, end=" ")
        inorder(root.right)

root = Node(10)
root.left = Node(20)
root.right = Node(30)
root.left.left = Node(40)

inorder(root)
# Out:
# 40 20 10 30

# %% [markdown]
# ## Binary Search Tree (BST)

# %%
class BSTNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insert(root, key):
    if root is None:
        return BSTNode(key)
    if key < root.data:
        root.left = insert(root.left, key)
    else:
        root.right = insert(root.right, key)
    return root

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data, end=" ")
        inorder(root.right)

root = None
for val in [50, 30, 70, 20, 40, 60, 80]:
    root = insert(root, val)

inorder(root)
# Out:
# 20 30 40 50 60 70 80

# %% [markdown]
# ## AVL Tree (Self-Balancing BST)

# %%
class AVLNode:
    def __init__(self, key):
        self.data = key
        self.left = None
        self.right = None
        self.height = 1

def get_height(node):
    if not node:
        return 0
    return node.height

def get_balance(node):
    if not node:
        return 0
    return get_height(node.left) - get_height(node.right)

def right_rotate(z):
    y = z.left
    T3 = y.right
    y.right = z
    z.left = T3
    z.height = 1 + max(get_height(z.left), get_height(z.right))
    y.height = 1 + max(get_height(y.left), get_height(y.right))
    return y

def left_rotate(z):
    y = z.right
    T2 = y.left
    y.left = z
    z.right = T2
    z.height = 1 + max(get_height(z.left), get_height(z.right))
    y.height = 1 + max(get_height(y.left), get_height(y.right))
    return y

def insert(root, key):
    if not root:
        return AVLNode(key)
    elif key < root.data:
        root.left = insert(root.left, key)
    else:
        root.right = insert(root.right, key)
    root.height = 1 + max(get_height(root.left), get_height(root.right))
    balance = get_balance(root)
    if balance > 1 and key < root.left.data:
        return right_rotate(root)
    if balance < -1 and key > root.right.data:
        return left_rotate(root)
    if balance > 1 and key > root.left.data:
        root.left = left_rotate(root.left)
        return right_rotate(root)
    if balance < -1 and key < root.right.data:
        root.right = right_rotate(root.right)
        return left_rotate(root)
    return root

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data, end=" ")
        inorder(root.right)

root = None
for val in [30, 20, 40, 10, 25, 50]:
    root = insert(root, val)

inorder(root)
# Out:
# 10 20 25 30 40 50

# %% [markdown]
# ## DSA problems

# %% [markdown]
# ## Find Maximum Element in a Binary Tree

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def find_max(root):
    if not root:
        return float('-inf')
    left_max = find_max(root.left)
    right_max = find_max(root.right)
    return max(root.data, left_max, right_max)

root = Node(10)
root.left = Node(20)
root.right = Node(5)
root.left.left = Node(30)

print("Maximum Element:", find_max(root))
# Out:
# Maximum Element: 30

# %% [markdown]
# ## 2. Count Number of Leaf Nodes in a Binary Tree

# %%
def count_leaves(root):
    if not root:
        return 0
    if not root.left and not root.right:
        return 1
    return count_leaves(root.left) + count_leaves(root.right)

root = Node(10)
root.left = Node(20)
root.right = Node(30)
root.left.left = Node(40)
root.left.right = Node(50)

print("Leaf Nodes Count:", count_leaves(root))
# Out:
# Leaf Nodes Count: 3

# %% [markdown]
# ## 3. Print All Root-to-Leaf Paths

# %%
def print_paths(root, path=[]):
    if not root:
        return
    path.append(root.data)
    if not root.left and not root.right:
        print(" -> ".join(map(str, path)))
    else:
        print_paths(root.left, path)
        print_paths(root.right, path)
    path.pop()

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

print("Root to Leaf Paths:")
print_paths(root)
# Out:
# Root to Leaf Paths:
# 1 -> 2 -> 4
# 1 -> 2 -> 5
# 1 -> 3

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/naynajn05/TNS_DSA.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in C:/Users/HP/.git/
# fatal: pathspec 'README.md' did not match any files
# On branch main
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.angular-config.json
# 	.cache/
# 	.config/
# 	.docker/
# 	.eclipse/
# 	.gitconfig
# 	.ipynb_checkpoints/
# 	.ipython/
# 	.jupyter/
# 	.keras/
# 	.m2/
# 	.matplotlib/
# 	.p2/
# 	.streamlit/
# 	.vscode/
# 	Angular Projects/
# 	Angular Workspace/
# 	AppData/
# 	Array 10.ipynb
# 	Array 11.ipynb
# 	Array 12.ipynb
# 	Array 13.ipynb
# 	Array 14.ipynb
# 	Array 4.ipynb
# 	Array 6.ipynb
# 	Array 7.ipynb
# 	Array 8.ipynb
# 	Array 9.ipynb
# 	Array OR.ipynb
# 	Array2.ipynb
# 	Array3.ipynb
# 	Array5.ipynb
# 	Bitwise.ipynb
# 	Biwise Array.ipynb
# 	Biwise OR.ipynb
# 	Building+a+CNN+-+MNIST.ipynb
# 	Capstoneone.ipynb
# 	Car-price-prediction-linear-regression-Intro-version.ipynb
# 	Contacts/
# 	Core Python (1).ipynb
# 	DIExample/
# 	DINew/
# 	DSA Module (Linked List).ipynb
# 	DSA Module(Queue).ipynb
# 	DSA Modules (Trees).ipynb
# 	DSA_Module_(Dictionary).ipynb
# 	DSA_Module_(List).ipynb
# 	DSA_Module_(Sets).ipynb
# 	DSA_Module_(Stack).ipynb
# 	DSA_Module_(Tuples).ipynb
# 	Data Hiding 2.ipynb
# 	Data Hiding.ipynb
# 	DayOne-angular/
# 	Decision tree
# 	DecisionTreeAssigment.ipynb
# 	Decision_Tree_IRIS.ipynb
# 	Decision_Tree_IRIS_1.ipynb
# 	Desktop/
# 	Directives_m.zip
# 	Directives_m/
# 	Documents/
# 	Downloads/
# 	Encapsulation.ipynb
# 	Ex 5 Movie lens.ipynb
# 	Favorites/
# 	Handwritten-Digit-MNIST-SVM.ipynb
# 	Housing Price_Linear Regression.ipynb
# 	Inheritance.ipynb
# 	Iris Example 1.ipynb
# 	JMUM14/
# 	K Means Algo.ipynb
# 	Linear Regression without sklearn.ipynb
# 	Linear regression with sklearn.ipynb
# 	Links/
# 	Logistic Regression.ipynb
# 	Logistic_Breast cancer.ipynb
# 	Logistic_Iris.ipynb
# 	Manufacturing Capstone Project.ipynb
# 	Microsoft/
# 	Music/
# 	NN_house_price_ANN.ipynb
# 	NTUSER.DAT
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TM.blf
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TMContainer00000000000000000001.regtrans-ms
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TMContainer00000000000000000002.regtrans-ms
# 	New Housing_Linear regression.ipynb
# 	OneDrive/
# 	PCA-Housing.ipynb
# 	Pictures/
# 	Polymorphism.ipynb
# 	ProductApplication/
# 	Python/
# 	Python_PCB.ipynb
# 	README.txt
# 	Random-Forest-Credit-Default-Prediction.ipynb
# 	Saved Games/
# 	Searches/
# 	TNSApp/
# 	TNS_DSA/
# 	Titanic.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled10.ipynb
# 	Untitled11.ipynb
# 	Untitled12.ipynb
# 	Untitled13.ipynb
# 	Untitled14.ipynb
# 	Untitled15.ipynb
# 	Untitled16.ipynb
# 	Untitled17.ipynb
# 	Untitled18.ipynb
# 	Untitled19.ipynb
# 	Untitled2.ipynb
# 	Untitled20.ipynb
# 	Untitled21.ipynb
# 	Untitled22.ipynb
# 	Untitled23.ipynb
# 	Untitled24.ipynb
# 	Untitled25.ipynb
# 	Untitled26.ipynb
# 	Untitled27.ipynb
# 	Untitled28.ipynb
# 	Untitled29.ipynb
# 	Untitled3.ipynb
# 	Untitled30.ipynb
# 	Untitled31.ipynb
# 	Untitled32.ipynb
# 	Untitled33.ipynb
# 	Untitled34.ipynb
# 	Untitled35.ipynb
# 	Untitled36.ipynb
# 	Untitled37.ipynb
# 	Untitled38.ipynb
# 	Untitled39.ipynb
# 	Untitled4.ipynb
# 	Untitled40.ipynb
# 	Untitled41.ipynb
# 	Untitled42.ipynb
# 	Untitled43.ipynb
# 	Untitled44.ipynb
# 	Untitled45.ipynb
# 	Untitled46.ipynb
# 	Untitled47.ipynb
# 	Untitled48.ipynb
# 	Untitled49.ipynb
# 	Untitled5.ipynb
# 	Untitled50.ipynb
# 	Untitled51.ipynb
# 	Untitled52.ipynb
# 	Untitled53.ipynb
# 	Untitled54.ipynb
# 	Untitled55.ipynb
# 	Untitled56.ipynb
# 	Untitled57.ipynb
# 	Untitled58.ipynb
# 	Untitled59.ipynb
# 	Untitled6.ipynb
# 	Untitled60.ipynb
# 	Untitled61.ipynb
# 	Untitled62.ipynb
# 	Untitled63.ipynb
# 	Untitled64.ipynb
# 	Untitled65.ipynb
# 	Untitled7.ipynb
# 	Untitled8.ipynb
# 	Untitled9.ipynb
# 	Videos/
# 	Wine Quality
# 	WineQT.csv
# 	angular_one.rar
# 	angular_one.zip
# 	angular_one/
# 	angularforms/
# 	angularintro/
# 	array1.ipynb
# 	churn_data.csv
# 	credit-card-default.csv
# 	customer_data.csv
# 	customer_segmentation_data.csv
# 	data.csv
# 	dependencyinjection/
# 	directives.zip
# 	directives/
# 	directivesdemo.zip
# 	directivesdemo/
# 	directivesexample.zip
# 	directivesexample/
# 	eclipse-java_workspace/
# 	eclipse-javaworkspace/
# 	eclipse-newworkspace/
# 	eclipse-workspace-AHM11/
# 	eclipse-workspace-CH01/
# 	eclipse-workspace-CH02/
# 	eclipse-workspace-IPS/
# 	eclipse-workspace-IPS1/
# 	eclipse-workspace-JMUM10/
# 	eclipse-workspace-JMUM12/
# 	eclipse-workspace-JMUM14/
# 	eclipse-workspace-NewJMUM12/
# 	eclipse-workspace-NewJMUM14/
# 	eclipse-workspace-Testing/
# 	eclipse-workspace-pnq07/
# 	eclipse-workspace-standard/
# 	eclipse-workspace/
# 	eclipse-workspace1/
# 	eclipse-workspace2/
# 	eclipse-workspaceAHM1/
# 	eclipse-workspaceB69/
# 	eclipse-workspaceIPS/
# 	eclipse-workspaceJN3/
# 	eclipse-workspaceM28/
# 	eclipse-workspace_AHM1/
# 	eclipse-workspace_AHM1_new/
# 	eclipse-workspaceexl/
# 	eclipse-workspacejmum08/
# 	eclipse-workspacejn04/
# 	eclipse-workspacem27/
# 	eclipse-workspacenew/
# 	eclipse-workspacenewm27/
# 	eclipse-workspacetest/
# 	eclipse/
# 	firstApp/
# 	git/
# 	housing.csv
# 	internet_data.csv
# 	investors_data.csv
# 	investors_group_1.csv
# 	investors_group_2.csv
# 	investors_new_information.csv
# 	linear_model.pkl
# 	linear_regression_model.pkl
# 	links.csv
# 	manufacturing_dataset_1000_samples.csv
# 	movies.csv
# 	newhousing.csv
# 	ntuser.dat.LOG1
# 	ntuser.dat.LOG2
# 	ntuser.ini
# 	play_tennis.csv
# 	product/
# 	ratings.csv
# 	scaler.pkl
# 	streamlit.py.code-workspace
# 	tags.csv
# 	telecom-churn-prediction-logistic-regression.ipynb
# 	titanic.csv
# 	untitled.py
# 	untitled1.py
# 	untitled2.py
# 	untitled3.py
#
# nothing added to commit but untracked files present (use "git add" to track)
# warning: could not open directory 'Application Data/': Permission denied
# warning: could not open directory 'Cookies/': Permission denied
# warning: could not open directory 'Local Settings/': Permission denied
# warning: could not open directory 'My Documents/': Permission denied
# warning: could not open directory 'NetHood/': Permission denied
# warning: could not open directory 'PrintHood/': Permission denied
# warning: could not open directory 'Recent/': Permission denied
# warning: could not open directory 'SendTo/': Permission denied
# warning: could not open directory 'Start Menu/': Permission denied
# warning: could not open directory 'Templates/': Permission denied
# error: remote origin already exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/naynajn05/TNS_Angular.git'

# %%
# !git remote -v
# Out:
# origin	https://github.com/naynajn05/TNS_Angular.git (fetch)
# origin	https://github.com/naynajn05/TNS_Angular.git (push)

# %%
# !git add .
# !git commit -m "Initial commit"
# Out:
# warning: could not open directory 'AppData/Local/Application Data/': Permission denied
# warning: could not open directory 'AppData/Local/History/': Permission denied
# warning: could not open directory 'AppData/Local/Microsoft/Windows/INetCache/Content.IE5/': Permission denied
# warning: could not open directory 'AppData/Local/Microsoft/Windows/INetCache/Low/Content.IE5/': Permission denied
# warning: could not open directory 'AppData/Local/Microsoft/Windows/Temporary Internet Files/': Permission denied
# warning: could not open directory 'AppData/Local/Temporary Internet Files/': Permission denied
# warning: could not open directory 'Application Data/': Permission denied
# warning: could not open directory 'Cookies/': Permission denied
# warning: could not open directory 'Documents/My Music/': Permission denied
# warning: could not open directory 'Documents/My Pictures/': Permission denied
# warning: could not open directory 'Documents/My Videos/': Permission denied
# warning: could not open directory 'Local Settings/': Permission denied
# warning: could not open directory 'My Documents/': Permission denied
# warning: could not open directory 'NetHood/': Permission denied
# warning: could not open directory 'PrintHood/': Permission denied
# warning: could not open directory 'Recent/': Permission denied
# warning: could not open directory 'SendTo/': Permission denied
# warning: could not open directory 'Start Menu/': Permission denied
# warning: could not open directory 'Templates/': Permission denied
# warning: in the working copy of '.angular-config.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.cache/tooling/gradle/versions.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.config/jgit/config', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.docker/config.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.docker/daemon.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.docker/models/layout.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.docker/models/models.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.docker/windows-daemon.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.gitconfig', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Array 10-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Array 4-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Array3-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Building+a+CNN+-+MNIST-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Capstoneone-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Car-price-prediction-linear-regression-Intro-version-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Core Python (1)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA Module (Linked List)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA_Module_(Dictionary)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA_Module_(List)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA_Module_(Sets)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA_Module_(Stack)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/DSA_Module_(Tuples)-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Decision_Tree_IRIS_1-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Ex 5 Movie lens-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Handwritten-Digit-MNIST-SVM-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/K Means Algo-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Logistic Regression-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Logistic_Breast cancer-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Logistic_Iris-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Manufacturing Capstone Project-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/NN_house_price_ANN-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/PCA-Housing-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled58-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled59-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled60-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled61-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled62-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled63-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled64-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Untitled65-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/telecom-churn-prediction-logistic-regression-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipython/profile_default/startup/README', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/antlr/antlr/2.7.7/antlr-2.7.7.jar.sha1', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/antlr/antlr/2.7.7/antlr-2.7.7.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/antlr/antlr/2.7.7/antlr-2.7.7.pom.sha1', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/aopalliance/aopalliance/1.0/aopalliance-1.0.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/aopalliance/aopalliance/1.0/aopalliance-1.0.pom.sha1', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/asm/asm-parent/3.3.1/asm-parent-3.3.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/asm/asm/3.3.1/asm-3.3.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/backport-util-concurrent/backport-util-concurrent/3.1/backport-util-concurrent-3.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/backport-util-concurrent/backport-util-concurrent/3.1/backport-util-concurrent-3.1.pom.sha1', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-classic/1.2.12/logback-classic-1.2.12.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-classic/1.4.5/logback-classic-1.4.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-classic/1.4.6/logback-classic-1.4.6.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-core/1.2.12/logback-core-1.2.12.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-core/1.4.5/logback-core-1.4.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-core/1.4.6/logback-core-1.4.6.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-parent/1.2.12/logback-parent-1.2.12.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-parent/1.4.5/logback-parent-1.4.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/ch/qos/logback/logback-parent/1.4.6/logback-parent-1.4.6.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/classworlds/classworlds/1.1-alpha-2/classworlds-1.1-alpha-2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/classworlds/classworlds/1.1-alpha-2/classworlds-1.1-alpha-2.pom.sha1', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/classworlds/classworlds/1.1/classworlds-1.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/datastax/oss/java-driver-bom/4.14.1/java-driver-bom-4.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/datastax/oss/java-driver-bom/4.15.0/java-driver-bom-4.15.0.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/datastax/oss/java-driver-bom/4.17.0/java-driver-bom-4.17.0.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/classmate/1.5.1/classmate-1.5.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/classmate/1.6.0/classmate-1.6.0.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/classmate/1.7.0/classmate-1.7.0.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-annotations/2.13.5/jackson-annotations-2.13.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-annotations/2.14.1/jackson-annotations-2.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-annotations/2.14.2/jackson-annotations-2.14.2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-annotations/2.15.3/jackson-annotations-2.15.3.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-annotations/2.17.1/jackson-annotations-2.17.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-core/2.13.5/jackson-core-2.13.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-core/2.14.1/jackson-core-2.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-core/2.14.2/jackson-core-2.14.2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-core/2.15.3/jackson-core-2.15.3.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-core/2.17.1/jackson-core-2.17.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-databind/2.13.5/jackson-databind-2.13.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-databind/2.14.1/jackson-databind-2.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-databind/2.14.2/jackson-databind-2.14.2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-databind/2.15.3/jackson-databind-2.15.3.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/core/jackson-databind/2.17.1/jackson-databind-2.17.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jdk8/2.13.5/jackson-datatype-jdk8-2.13.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jdk8/2.14.1/jackson-datatype-jdk8-2.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jdk8/2.14.2/jackson-datatype-jdk8-2.14.2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jdk8/2.15.3/jackson-datatype-jdk8-2.15.3.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jdk8/2.17.1/jackson-datatype-jdk8-2.17.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jsr310/2.13.5/jackson-datatype-jsr310-2.13.5.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jsr310/2.14.1/jackson-datatype-jsr310-2.14.1.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-jsr310/2.14.2/jackson-datatype-jsr310-2.14.2.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/com/fasterxml/jackson/datatype/jackson-datatype-
pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/jakarta/persistence/jakarta.persistence-api/2.2.3/jakarta.persistence-api-2.2.3.pom', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.m2/repository/jakarta/persistence/jakarta.persistence-api/3.1.0/jakarta.persistence-api-3.1.0.pom', LF will be replaced by CRLF the next time Git touches it
# ...
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/e2e/src/app.po.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/e2e/tsconfig.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/karma.conf.js', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/package-lock.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/package.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_components/alert.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_components/alert.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_components/index.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_helpers/auth.guard.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_helpers/error.interceptor.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_helpers/fake-backend.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_helpers/index.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_helpers/jwt.interceptor.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_models/alert.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_models/index.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_models/user.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_services/account.service.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_services/alert.service.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/_services/index.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/account-routing.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/account.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/layout.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/layout.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/login.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/login.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/register.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/account/register.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/app-routing.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/app.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/app.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/app.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/home/home.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/home/home.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/add-edit.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/add-edit.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/layout.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/layout.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/list.component.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/list.component.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/users-routing.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/app/users/users.module.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/environments/environment.prod.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/environments/environment.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/index.html', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/main.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/polyfills.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/styles.less', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/src/test.ts', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/tsconfig.app.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/tsconfig.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/tsconfig.spec.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Angular Workspace/angular-9-registration-login-example-master2/tslint.json', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'AppData/Local/AMD/CN/cmdb.blb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'AppData/Local/AMD/CN/gallery.blb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'AppData/Local/AMD/CN/gmdb.blb', LF will be replaced by CRLF the next time Git touches it
# error: open("AppData/Local/AMD/DxCache/3fc486d7cd0c61d1.2622c26ef9ddc178.7b1f799a.dad1858.0.parc"): Permission denied
# error: unable to index file 'AppData/Local/AMD/DxCache/3fc486d7cd0c61d1.2622c26ef9ddc178.7b1f799a.dad1858.0.parc'
# fatal: adding files failed
# On branch main
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.angular-config.json
# 	.cache/
# 	.config/
# 	.docker/
# 	.eclipse/
# 	.gitconfig
# 	.ipynb_checkpoints/
# 	.ipython/
# 	.jupyter/
# 	.keras/
# 	.m2/
# 	.matplotlib/
# 	.p2/
# 	.streamlit/
# 	.vscode/
# 	Angular Projects/
# 	Angular Workspace/
# 	AppData/
# 	Array 10.ipynb
# 	Array 11.ipynb
# 	Array 12.ipynb
# 	Array 13.ipynb
# 	Array 14.ipynb
# 	Array 4.ipynb
# 	Array 6.ipynb
# 	Array 7.ipynb
# 	Array 8.ipynb
# 	Array 9.ipynb
# 	Array OR.ipynb
# 	Array2.ipynb
# 	Array3.ipynb
# 	Array5.ipynb
# 	Bitwise.ipynb
# 	Biwise Array.ipynb
# 	Biwise OR.ipynb
# 	Building+a+CNN+-+MNIST.ipynb
# 	Capstoneone.ipynb
# 	Car-price-prediction-linear-regression-Intro-version.ipynb
# 	Contacts/
# 	Core Python (1).ipynb
# 	DIExample/
# 	DINew/
# 	DSA Module (Linked List).ipynb
# 	DSA Module(Queue).ipynb
# 	DSA Modules (Trees).ipynb
# 	DSA_Module_(Dictionary).ipynb
# 	DSA_Module_(List).ipynb
# 	DSA_Module_(Sets).ipynb
# 	DSA_Module_(Stack).ipynb
# 	DSA_Module_(Tuples).ipynb
# 	Data Hiding 2.ipynb
# 	Data Hiding.ipynb
# 	DayOne-angular/
# 	Decision tree
# 	DecisionTreeAssigment.ipynb
# 	Decision_Tree_IRIS.ipynb
# 	Decision_Tree_IRIS_1.ipynb
# 	Desktop/
# 	Directives_m.zip
# 	Directives_m/
# 	Documents/
# 	Downloads/
# 	Encapsulation.ipynb
# 	Ex 5 Movie lens.ipynb
# 	Favorites/
# 	Handwritten-Digit-MNIST-SVM.ipynb
# 	Housing Price_Linear Regression.ipynb
# 	Inheritance.ipynb
# 	Iris Example 1.ipynb
# 	JMUM14/
# 	K Means Algo.ipynb
# 	Linear Regression without sklearn.ipynb
# 	Linear regression with sklearn.ipynb
# 	Links/
# 	Logistic Regression.ipynb
# 	Logistic_Breast cancer.ipynb
# 	Logistic_Iris.ipynb
# 	Manufacturing Capstone Project.ipynb
# 	Microsoft/
# 	Music/
# 	NN_house_price_ANN.ipynb
# 	NTUSER.DAT
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TM.blf
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TMContainer00000000000000000001.regtrans-ms
# 	NTUSER.DAT{7be2378b-5a5f-11f0-9675-bf83caf39cb1}.TMContainer00000000000000000002.regtrans-ms
# 	New Housing_Linear regression.ipynb
# 	OneDrive/
# 	PCA-Housing.ipynb
# 	Pictures/
# 	Polymorphism.ipynb
# 	ProductApplication/
# 	Python/
# 	Python_PCB.ipynb
# 	README.txt
# 	Random-Forest-Credit-Default-Prediction.ipynb
# 	Saved Games/
# 	Searches/
# 	TNSApp/
# 	TNS_DSA/
# 	Titanic.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled10.ipynb
# 	Untitled11.ipynb
# 	Untitled12.ipynb
# 	Untitled13.ipynb
# 	Untitled14.ipynb
# 	Untitled15.ipynb
# 	Untitled16.ipynb
# 	Untitled17.ipynb
# 	Untitled18.ipynb
# 	Untitled19.ipynb
# 	Untitled2.ipynb
# 	Untitled20.ipynb
# 	Untitled21.ipynb
# 	Untitled22.ipynb
# 	Untitled23.ipynb
# 	Untitled24.ipynb
# 	Untitled25.ipynb
# 	Untitled26.ipynb
# 	Untitled27.ipynb
# 	Untitled28.ipynb
# 	Untitled29.ipynb
# 	Untitled3.ipynb
# 	Untitled30.ipynb
# 	Untitled31.ipynb
# 	Untitled32.ipynb
# 	Untitled33.ipynb
# 	Untitled34.ipynb
# 	Untitled35.ipynb
# 	Untitled36.ipynb
# 	Untitled37.ipynb
# 	Untitled38.ipynb
# 	Untitled39.ipynb
# 	Untitled4.ipynb
# 	Untitled40.ipynb
# 	Untitled41.ipynb
# 	Untitled42.ipynb
# 	Untitled43.ipynb
# 	Untitled44.ipynb
# 	Untitled45.ipynb
# 	Untitled46.ipynb
# 	Untitled47.ipynb
# 	Untitled48.ipynb
# 	Untitled49.ipynb
# 	Untitled5.ipynb
# 	Untitled50.ipynb
# 	Untitled51.ipynb
# 	Untitled52.ipynb
# 	Untitled53.ipynb
# 	Untitled54.ipynb
# 	Untitled55.ipynb
# 	Untitled56.ipynb
# 	Untitled57.ipynb
# 	Untitled58.ipynb
# 	Untitled59.ipynb
# 	Untitled6.ipynb
# 	Untitled60.ipynb
# 	Untitled61.ipynb
# 	Untitled62.ipynb
# 	Untitled63.ipynb
# 	Untitled64.ipynb
# 	Untitled65.ipynb
# 	Untitled7.ipynb
# 	Untitled8.ipynb
# 	Untitled9.ipynb
# 	Videos/
# 	Wine Quality
# 	WineQT.csv
# 	angular_one.rar
# 	angular_one.zip
# 	angular_one/
# 	angularforms/
# 	angularintro/
# 	array1.ipynb
# 	churn_data.csv
# 	credit-card-default.csv
# 	customer_data.csv
# 	customer_segmentation_data.csv
# 	data.csv
# 	dependencyinjection/
# 	directives.zip
# 	directives/
# 	directivesdemo.zip
# 	directivesdemo/
# 	directivesexample.zip
# 	directivesexample/
# 	eclipse-java_workspace/
# 	eclipse-javaworkspace/
# 	eclipse-newworkspace/
# 	eclipse-workspace-AHM11/
# 	eclipse-workspace-CH01/
# 	eclipse-workspace-CH02/
# 	eclipse-workspace-IPS/
# 	eclipse-workspace-IPS1/
# 	eclipse-workspace-JMUM10/
# 	eclipse-workspace-JMUM12/
# 	eclipse-workspace-JMUM14/
# 	eclipse-workspace-NewJMUM12/
# 	eclipse-workspace-NewJMUM14/
# 	eclipse-workspace-Testing/
# 	eclipse-workspace-pnq07/
# 	eclipse-workspace-standard/
# 	eclipse-workspace/
# 	eclipse-workspace1/
# 	eclipse-workspace2/
# 	eclipse-workspaceAHM1/
# 	eclipse-workspaceB69/
# 	eclipse-workspaceIPS/
# 	eclipse-workspaceJN3/
# 	eclipse-workspaceM28/
# 	eclipse-workspace_AHM1/
# 	eclipse-workspace_AHM1_new/
# 	eclipse-workspaceexl/
# 	eclipse-workspacejmum08/
# 	eclipse-workspacejn04/
# 	eclipse-workspacem27/
# 	eclipse-workspacenew/
# 	eclipse-workspacenewm27/
# 	eclipse-workspacetest/
# 	eclipse/
# 	firstApp/
# 	git/
# 	housing.csv
# 	internet_data.csv
# 	investors_data.csv
# 	investors_group_1.csv
# 	investors_group_2.csv
# 	investors_new_information.csv
# 	linear_model.pkl
# 	linear_regression_model.pkl
# 	links.csv
# 	manufacturing_dataset_1000_samples.csv
# 	movies.csv
# 	newhousing.csv
# 	ntuser.dat.LOG1
# 	ntuser.dat.LOG2
# 	ntuser.ini
# 	play_tennis.csv
# 	product/
# 	ratings.csv
# 	scaler.pkl
# 	streamlit.py.code-workspace
# 	tags.csv
# 	telecom-churn-prediction-logistic-regression.ipynb
# 	titanic.csv
# 	untitled.py
# 	untitled1.py
# 	untitled2.py
# 	untitled3.py
#
# nothing added to commit but untracked files present (use "git add" to track)
# warning: could not open directory 'Application Data/': Permission denied
# warning: could not open directory 'Cookies/': Permission denied
# warning: could not open directory 'Local Settings/': Permission denied
# warning: could not open directory 'My Documents/': Permission denied
# warning: could not open directory 'NetHood/': Permission denied
# warning: could not open directory 'PrintHood/': Permission denied
# warning: could not open directory 'Recent/': Permission denied
# warning: could not open directory 'SendTo/': Permission denied
# warning: could not open directory 'Start Menu/': Permission denied
# warning: could not open directory 'Templates/': Permission denied

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/naynajn05/TNS_Angular.git'

# %%
# !git remote add origin https://github.com/naynajn05/TNS_DSA.git
# !git branch -M main
# !git push -u origin main
# Out:
# error: remote origin already exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/naynajn05/TNS_Angular.git'
